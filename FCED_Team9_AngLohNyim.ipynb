# %%
import numpy as np   

import pandas as pd   

import seaborn as sb   

import matplotlib.pyplot as plt   

sb.set()   #means to set the default seaborn style 

from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression   

from sklearn.model_selection import train_test_split   

from sklearn.metrics import mean_squared_error   

from sklearn.ensemble import GradientBoostingRegressor

from sklearn.tree import DecisionTreeClassifier  

from sklearn.tree import export_graphviz  

from sklearn.metrics import confusion_matrix  

from sklearn.tree import plot_tree 

from sklearn.preprocessing import OneHotEncoder

from sklearn.pipeline import Pipeline

from sklearn.metrics import explained_variance_score

from sklearn.metrics import accuracy_score

# %%
redWine = pd.read_csv('Red.csv')
redWine['Type'] = 1
redWine.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year  Type
# 0  Château La Providence     4.2              100  95.00  2011     1
# 1     Château Mont-Redon     4.3              100  15.50  2017     1
# 2             Renzo Masi     3.9              100   7.45  2015     1
# 3             Cavalchina     3.5              100   8.72  2019     1
# 4            Markowitsch     3.9              100  29.15  2016     1

# %%
average_price = redWine['Price'].mean()
print("Average price of red wine:", average_price)
# Out:
# Average price of red wine: 39.14506462035541

# %%
rose = pd.read_csv('Rose.csv')
rose['Type'] = 2
rose.head()
# Out:
#                                Name   Country        Region  \
# 0        Mad Méditerranée Rosé 2019    France  Méditerranée
# 1                  Redoma Rosé 2019  Portugal         Douro
# 2  Fantini Cerasuolo d'Abruzzo 2019     Italy       Abruzzo
# 3            Mount Hermon Rosé 2017    Israel       Galilee
# 4                La Villa Rosé 2018    France     Languedoc
#
#                    Winery  Rating  NumberOfRatings  Price  Year  Type
# 0      Château Camparnaud     4.0               25  10.11  2019     2
# 1                Niepoort     3.9               25  12.81  2019     2
# 2                 Farnese     3.6               25   5.60  2019     2
# 3                  Hermon     3.4               25  12.14  2017     2
# 4  Château La Sauvageonne     4.6               25  68.95  2018     2

# %%
average_price = rose['Price'].mean()
print("Average price of rose wine:", average_price)
# Out:
# Average price of rose wine: 12.525743073047858

# %%
sparkling = pd.read_csv('Sparkling.csv')
sparkling['Type'] = 3
sparkling.head()
# Out:
#                                           Name      Country  \
# 0                   Crémant de Loire Brut 2017       France
# 1  Vicar's Choice Sauvignon Blanc Bubbles 2019  New Zealand
# 2                  Crémant de Limoux Brut N.V.       France
# 3                            Athesis Brut 2016        Italy
# 4     Blanc de Blancs Réserve Brut Nature N.V.      Germany
#
#                   Region            Winery  Rating  NumberOfRatings  Price  \
# 0       Crémant de Loire  Langlois-Chateau     3.9               25  14.41
# 1            Marlborough       Saint Clair     4.2               25  11.90
# 2      Crémant de Limoux       Prima Perla     3.5               25  14.32
# 3  Südtirol - Alto Adige          Kettmeir     4.0               25  21.50
# 4                  Pfalz            Eymann     3.9               25  31.18
#
#    Year  Type
# 0  2017     3
# 1  2019     3
# 2  N.V.     3
# 3  2016     3
# 4  N.V.     3

# %%
average_price = sparkling['Price'].mean()
print("Average price of sparkling wine:", average_price)
# Out:
# Average price of sparkling wine: 34.80342601787487

# %%
whiteWine = pd.read_csv('White.csv')
whiteWine['Type'] = 4
whiteWine.head()
# Out:
#                       Name  Country                      Region  \
# 0          Vermentino 2017    Italy                     Toscana
# 1        Ronco Broilo 2010    Italy  Colli Orientali del Friuli
# 2  Weisser Schiefer s 2017  Austria               Südburgenland
# 3          Chardonnay 2018  Germany                 Rheinhessen
# 4     Maganza Zibibbo 2018    Italy             Terre Siciliane
#
#                     Winery  Rating  NumberOfRatings  Price  Year  Type
# 0      Famiglia Castellani     3.8               25   5.65  2017     4
# 1  Conte d'Attimis Maniago     4.3               25  44.90  2010     4
# 2     Weinbau Uwe Schiefer     4.2               25  33.25  2017     4
# 3        Krämer - Straight     3.9               25   8.99  2018     4
# 4                Luna Gaia     3.9               25   8.60  2018     4

# %%
average_price = whiteWine['Price'].mean()
print("Average price of whiteWine wine:", average_price)
# Out:
# Average price of whiteWine wine: 20.620318809776833

# %%
print("Red Wine Data Type: ")
print("Data type : ", type(redWine))
print("Data dims : ", redWine.shape)
print('')
print("White Wine Data Type: ")
print("Data type : ", type(whiteWine))
print("Data dims : ", whiteWine.shape)
print('')
print("Rose Wine Data Type: ")
print("Data type : ", type(rose))
print("Data dims : ", rose.shape)
print('')
print("Sparkling Wine Data Type: ")
print("Data type : ", type(sparkling))
print("Data dims : ", sparkling.shape)
# Out:
# Red Wine Data Type:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (8666, 9)
#
# White Wine Data Type:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (3764, 9)
#
# Rose Wine Data Type:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (397, 9)
#
# Sparkling Wine Data Type:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1007, 9)

# %%
wineData = pd.concat([redWine, whiteWine, rose, sparkling])
wineData.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year  Type
# 0  Château La Providence     4.2              100  95.00  2011     1
# 1     Château Mont-Redon     4.3              100  15.50  2017     1
# 2             Renzo Masi     3.9              100   7.45  2015     1
# 3             Cavalchina     3.5              100   8.72  2019     1
# 4            Markowitsch     3.9              100  29.15  2016     1

# %% [markdown]
# Calculating, the max price, And calculating the average price of wine for each country.

# %%
max_price_per_country = wineData.groupby('Country')['Price'].max().sort_values(ascending=False)

avg_price_per_country = wineData.groupby('Country')['Price'].mean().sort_values(ascending=False)

min_price = wineData[wineData['Price'] == wineData['Price'].min()]

print("Maximum price of wine for each country:")
print(max_price_per_country)

print("\nAverage price of wine for each country:")
print(avg_price_per_country)

print("\nCheapest wine:")
min_price
# Out:
# Maximum price of wine for each country:
# Country
# France            3410.79
# Italy             1115.50
# Australia          730.12
# United States      721.34
# Spain              672.60
# Germany            554.10
# South Africa       463.03
# Argentina          273.71
# Chile              239.00
# Austria            149.00
# Portugal           136.47
# New Zealand        135.00
# Moldova             98.98
# Brazil              73.06
# Switzerland         70.19
# United Kingdom      62.29
# Lebanon             53.52
# Greece              36.95
# Turkey              35.00
# China               35.00
# Israel              34.90
# Luxembourg          33.00
# Georgia             32.90
# Slovenia            32.87
# Romania             29.50
# Croatia             28.90
# Czech Republic      28.90
# Hungary             24.50
# Slovakia            19.90
# Uruguay             15.90
# Canada              14.95
# Bulgaria            11.43
# Mexico               8.65
# ...

# %%
correlation_matrix = wineData['Type'].corr(wineData['Price'])
print("Correlation between Type and Price:")
print(correlation_matrix)

#This correlation value isnt very usefull because of one hot ecoding Type Categorical against Numerical Price
# Out:
# Correlation between Type and Price:
# -0.11029515232544741

# %%
cleaned_wineData = wineData[~wineData['Year'].str.contains('N.V.')]
correlation_matrix = cleaned_wineData['Year'].corr(wineData['Price'])
print("Correlation between Year and Price:")
print(correlation_matrix)
# Out:
# Correlation between Year and Price:
# -0.19900864354034803

# %%
correlation_matrix = cleaned_wineData['Rating'].corr(wineData['Price'])
print("Correlation between Rating and Price:", correlation_matrix)
# Out:
# Correlation between Rating and Price: 0.25647582433722527

# %%
print("Wine Data Type: ")
print("Data type : ", type(wineData))
print("Data dims : ", wineData.shape)
# Out:
# Wine Data Type:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (13834, 9)

# %% [markdown]
# The wine types have overlap, they differ by year. E.g. Wine1 2018 vs Wine1 2016, not sure how to extract this information since not every type categorise by the year even though they have information on the production year

# %%
f, axes = plt.subplots(2, 3, figsize=(24, 12))

sb.boxplot(data = wineData["Rating"], orient = "h", ax = axes[0,0])
sb.histplot(data = wineData["Rating"], ax = axes[0,1])
sb.violinplot(data = wineData["Rating"], orient = "h", ax = axes[0,2])

sb.boxplot(data = wineData["Price"], orient = "h", ax = axes[1,0])
sb.histplot(data = wineData["Price"], ax = axes[1,1])
sb.violinplot(data = wineData["Price"], orient = "h", ax = axes[1,2])
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# Note: Joint plot not useful for visualisation for now due to presence of extreme data (just add it on later after cleaning) Categorical one should be nicer I think? The data cleaning is below

# %%
Q1_Price = wineData['Price'].quantile(0.25)
Q3_Price = wineData['Price'].quantile(0.75)
IQR_Price = Q3_Price - Q1_Price
outliers_Price = wineData[(wineData['Price'] < Q1_Price - 1.5 * IQR_Price) | (wineData['Price'] > Q3_Price + 1.5 * IQR_Price)]

# %%
wineData = wineData.drop(outliers_Price.index)

# %%
f, axes = plt.subplots(1, 3, figsize=(24, 4))

sb.boxplot(data=wineData['Price'], orient="h", ax=axes[0])
axes[0].set_title('Boxplot')

sb.histplot(data=wineData['Price'], ax=axes[1])
axes[1].set_title('Histogram')

sb.violinplot(data=wineData['Price'], orient="h", ax=axes[2])
axes[2].set_title('Violinplot')

plt.show()

# %%
f, axes = plt.subplots(1, 3, figsize=(24, 4))

sb.boxplot(data=wineData['Rating'], orient="h", ax=axes[0])
axes[0].set_title('Boxplot')

sb.histplot(data=wineData['Rating'], ax=axes[1])
axes[1].set_title('Histogram')

sb.violinplot(data=wineData['Rating'], orient="h", ax=axes[2])
axes[2].set_title('Violinplot')

plt.show()

# %% [markdown]
# Not sure how to make the violin plot smoother

# %%
print("Origin Countries :", len(wineData["Country"].unique()))

wineData["Country"].value_counts()
sb.catplot(y = "Country", data = wineData, kind = "count", height = 8)
# Out:
# Origin Countries : 33

# %%
rating = pd.DataFrame(wineData['Rating'])
price = pd.DataFrame(wineData['Price'])
year = pd.DataFrame(wineData['Year'])
wineType = pd.DataFrame(wineData['Type'])
region = pd.DataFrame(wineData['Region'])
country = pd.DataFrame(wineData["Country"])
price_rating = pd.concat([rating, price], axis = 1).reindex(rating.index)

# %%
sb.jointplot(data = price_rating, x = "Rating", y = "Price", height = 12)

# %%
print("Origin Countries :", len(wineData["Year"].unique()))

wineData["Year"].value_counts()
wineData_sorted = wineData.sort_values(by='Year',ascending=False)
sb.catplot(y = "Year", data = wineData_sorted, kind = "count", height = 8)
# Out:
# Origin Countries : 27

# %% [markdown]
# Year seems to be useful but thinking how to correlate/whether further data cleaning needed

# %% [markdown]
# possible problem statement could be what makes the best rating at the cheapest price? or we could see the average rating for each country? which country has the best ratings? or which data has the best correlation with the rating?

# %% [markdown]
# 1. finding what makes the best rating?

# %% [markdown]
# 2. identifying wine trends or prices for Optimizing pricing strategies on wine sales?

# %% [markdown]
# ### Gradient boosted model:
#
# Predict Rating

# %%
cleaned_wineData = wineData[~wineData['Year'].str.contains('N.V.')]
cleaned_wineData
# Out:
#                                              Name      Country  \
# 1                                      Lirac 2017       France
# 2              Erta e China Rosso di Toscana 2015        Italy
# 3                                  Bardolino 2019        Italy
# 5                Gigondas (Nobles Terrasses) 2017       France
# 6               Marion's Vineyard Pinot Noir 2016  New Zealand
# ..                                            ...          ...
# 790            Rosé Brut Champagne (Vintage) 2011       France
# 797                 Brut Millésimé Champagne 2006       France
# 814              Concerto Lambrusco Reggiano 2017        Italy
# 824  Brut Champagne (Extra Cuvée de Réserve) 2012       France
# 837          Arte Tradicional Brut Espumante 2017       Brazil
#
#                 Region              Winery  Rating  NumberOfRatings  Price  \
# 1                Lirac  Château Mont-Redon     4.3              100  15.50
# ...

# %%
reqData1 = cleaned_wineData[['Year', 'Type', 'Country']]
rating = cleaned_wineData[['Rating']]

# %%
X1 = reqData1
y1 = rating

# Split the data into training and testing sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=5)

# Define which features are categorical
categorical_features = ['Country']

# Create a pipeline for preprocessing
preprocessor = ColumnTransformer(
    transformers=[('cat', OneHotEncoder(), categorical_features)], remainder='passthrough')

# Initialize Gradient Boosted Tree regressor
gbt_regressor = GradientBoostingRegressor()

# Create a pipeline with preprocessing and the model
pipeline = Pipeline(steps=[('preprocessor', preprocessor),('regressor', gbt_regressor)])

# Fit the model to the training data
pipeline.fit(X_train1, y_train1)

# Predict ratings for the test set
y_pred1 = pipeline.predict(X_test1)

# Calculate Mean Squared Error (MSE) on the test set
print("Goodness of Fit of Model \tTest Dataset")
mse = mean_squared_error(y_test1, y_pred1)
print("Mean Squared Error:", mse)
explained_variance1 = explained_variance_score(y_test1, y_pred1)
print("Explained Variance Score:", explained_variance1)
# Out:
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Goodness of Fit of Model 	Test Dataset
# Mean Squared Error: 0.06648377417863918
# Explained Variance Score: 0.09785739757726375

# %%
predicted_rating = pd.DataFrame({'Predicted Rating': y_pred1.squeeze(), 'Actual Rating': y_test1.squeeze()})
predicted_rating
# Out:
#       Predicted Rating  Actual Rating
# 3668          3.717337            3.7
# 3556          3.824118            3.8
# 8619          3.836478            3.5
# 2382          3.794079            3.4
# 6018          3.945296            4.1
# ...                ...            ...
# 6766          3.898497            3.7
# 1277          3.752072            3.8
# 7857          3.843549            4.1
# 3090          3.752820            3.8
# 1994          3.755038            3.4
#
# [2194 rows x 2 columns]

# %%
sb.jointplot(data = predicted_rating, x = "Predicted Rating", y = "Actual Rating", height = 12)

# %%
forjoining_rating = pd.DataFrame(predicted_rating['Predicted Rating'])

# %%
correctX_test = pd.concat([X_test1, forjoining_rating], axis = 1).reindex(X_test1.index)
correctX_test.rename(columns={'Predicted Rating': 'Rating'}, inplace=True)
correctX_test
# Out:
#       Year  Type        Country    Rating
# 3668  2016     4          Chile  3.717337
# 3556  2018     4        Germany  3.824118
# 8619  2016     1          Spain  3.836478
# 2382  2017     4  United States  3.794079
# 6018  2013     1          Italy  3.945296
# ...    ...   ...            ...       ...
# 6766  2016     1          Italy  3.898497
# 1277  2017     1        Romania  3.752072
# 7857  2016     1         France  3.843549
# 3090  2018     4         France  3.752820
# 1994  2018     4          Italy  3.755038
#
# [2194 rows x 4 columns]

# %% [markdown]
# Predict Price

# %%
reqData2 = cleaned_wineData[['Year', 'Type', 'Country', 'Rating']]
price2 = cleaned_wineData[['Price']]

# %%
# Split the data into features (X2) and target variable (y2)
X2 = reqData2
y2 = price2

# Split the data into training and testing sets
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=5)

# Assuming correctX_test is provided

X_test2 = correctX_test

# Define which features are categorical
categorical_features = ['Country']

# Create a pipeline for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), categorical_features)
    ], remainder='passthrough')

# Initialize Gradient Boosted Tree regressor
gbt_regressor = GradientBoostingRegressor()

# Create a pipeline with preprocessing and the model
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('regressor', gbt_regressor)])

# Fit the model to the training data
pipeline.fit(X_train2, y_train2)

# Predict prices for the test set
y_pred2 = pipeline.predict(X_test2)

# Calculate Mean Squared Error (MSE) on the test set

print("Goodness of Fit of Model \tTest Dataset")
mse = mean_squared_error(y_test2, y_pred2)
print("Mean Squared Error:", mse)
explained_variance2 = explained_variance_score(y_test2, y_pred2)
print("Explained Variance Score:", explained_variance2)
# Out:
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/ensemble/_gb.py:424: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Goodness of Fit of Model 	Test Dataset
# Mean Squared Error: 131.70090016792176
# Explained Variance Score: 0.28758291464009855

# %%
predicted_price = pd.DataFrame({'Predicted Price': y_pred2.squeeze(), 'Actual Price': y_test2.squeeze()})
predicted_price
# Out:
#       Predicted Price  Actual Price
# 3668        14.450029         13.16
# 3556        12.479372          8.50
# 8619        14.520855         12.20
# 2382        17.920201          7.65
# 6018        26.124398         29.90
# ...               ...           ...
# 6766        18.632916          5.49
# 1277        13.581090         13.50
# 7857        20.934609         36.85
# 3090        15.256193         19.69
# 1994        11.883275          8.93
#
# [2194 rows x 2 columns]

# %%
sb.jointplot(data = predicted_price, x = "Predicted Price", y = "Actual Price", height = 12)

# %% [markdown]
# ### Tree Regression:

# %%
reqData2 = cleaned_wineData[['Year', 'Type', 'Country', 'Rating']]
price2 = cleaned_wineData['Price']
X_train1, X_test1, y_train1, y_test1 = train_test_split(reqData2, price2, test_size=0.2, random_state=5)

# %%
# just testing
#for DecisionTreeClassifier
# typical to have numerical variables as predictors predicting a categorical 
#(discrete) variable, rather than predicting a numerical variable.

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd


dectree = DecisionTreeRegressor(max_depth=3)


X = reqData2[["Rating"]]
y = price2

X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.2, random_state=5)

dectree.fit(X_train1, y_train1)

y_pred = dectree.predict(X_test1)

# Evaluating the performance using Mean Squared Error (MSE)
mse = mean_squared_error(y_test1, y_pred)
print("Mean Squared Error:", mse)

# Visualizing the decision tree (optional)
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 20))
plot_tree(dectree, feature_names=X.columns, filled=True, rounded=True)
plt.show()
# Out:
# Mean Squared Error: 110.24948354266508

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

X = reqData2[['Year', 'Type', 'Country']]
y = reqData2["Rating"]

encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=5)


dectree = DecisionTreeRegressor(max_depth=4)
dectree.fit(X_train, y_train)

y_pred = dectree.predict(X_test) #added this line
mse = mean_squared_error(y_test, y_pred) #added this line
print("Mean Squared Error:", mse) #added this line

explained_variance = explained_variance_score(y_test, y_pred)
print("Explained Variance Score:", explained_variance)

plt.figure(figsize=(25,14))
plot_tree(dectree, feature_names=encoder.get_feature_names_out(['Year', 'Type', 'Country']), filled=True, rounded=True, fontsize=8)
plt.show()
# Out:
# Mean Squared Error: 0.0694714432343496
# Explained Variance Score: 0.057553844447549296

# %% [markdown]
# This means that Year followed by country followed by type is more likely to influence ratings.

# %%
X = reqData2[['Year', 'Type', 'Country']]
y = reqData2["Rating"]

# One-hot encoding to convert categorical variables into numerical format
encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X)

dectree = DecisionTreeRegressor(max_depth=3)
dectree.fit(X_encoded, y)

Rating_predicted = dectree.predict(X_encoded)

#to obtain predicted ratiings

#________________________________________






predicted_data = pd.DataFrame({'Year': X['Year'], 'Type': X['Type'], 'Country': X['Country'], 'Predicted_Rating': Rating_predicted})
X = predicted_data
y = price2

encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X)

X_train1, X_test1, y_train1, y_test1 = train_test_split(X_encoded, y, test_size=0.2, random_state=5)


# Initialize and fit the decision tree regressor
dectree = DecisionTreeRegressor(max_depth=4)
dectree.fit(X_train1, y_train1)

y_pred = dectree.predict(X_test1) #added this line
mse = mean_squared_error(y_test1, y_pred) #added this line
print("Mean Squared Error:", mse) #added this line

explained_variance = explained_variance_score(y_test1, y_pred)

print("Explained Variance Score:", explained_variance)

# Get feature names after one-hot encoding
feature_names = encoder.get_feature_names_out(['Year', 'Type', 'Country', 'Predicted_Rating'])

# Plot the decision tree
plt.figure(figsize=(25,14))
plot_tree(dectree, feature_names=feature_names, filled=True, rounded=True, fontsize=8)
plt.show()
# Out:
# Mean Squared Error: 135.42311923233788
# Explained Variance Score: 0.2624132045212676

# %%
predicted_data
# Out:
#      Year  Type      Country  Predicted_Rating
# 1    2017     1       France          3.794152
# 2    2015     1        Italy          3.879307
# 3    2019     1        Italy          3.774260
# 5    2017     1       France          3.794152
# 6    2016     1  New Zealand          3.879307
# ..    ...   ...          ...               ...
# 790  2011     3       France          3.879307
# 797  2006     3       France          3.879307
# 814  2017     3        Italy          3.794152
# 824  2012     3       France          3.879307
# 837  2017     3       Brazil          3.794152
#
# [10966 rows x 4 columns]

# %%
import numpy as np


correlation = np.corrcoef(y_pred, y_test1)[0, 1]

print("Correlation between predicted ratings and prices:", correlation)
# Out:
# Correlation between predicted ratings and prices: 0.5130501690968069

# %% [markdown]
# Using predicted ratings to predict

# %%
X = reqData2[['Year', 'Type', 'Country', 'Rating']] #Without predicited ratings
y = price2

# One-hot encode categorical features (including 'Rating')
encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X).toarray()  #one hot ecoding even rating like a categorical data.

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=5)

# Initialize and fit the decision tree regressor
dectree = DecisionTreeRegressor(max_depth=3)
dectree.fit(X_train, y_train)

y_pred = dectree.predict(X_test) #added this line
mse = mean_squared_error(y_test, y_pred) #added this line
print("Mean Squared Error:", mse) #added this line

# Get feature names after one-hot encoding
feature_names = encoder.get_feature_names_out(['Year', 'Type', 'Country', 'Rating'])

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(dectree, feature_names=feature_names, filled=True, rounded=True)
plt.show()
# Out:
# Mean Squared Error: 142.43527124693415

# %% [markdown]
# Without predicted ratings

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

reqData3 = cleaned_wineData[['Year', 'Type', 'Country', 'Rating']]
price3 = cleaned_wineData['Price']

# %%
# Splitting data into features (X) and target variable (y)
X = reqData3[['Year', 'Type', 'Country']]
y = reqData3["Rating"]

# Splitting data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# One-hot encoding categorical variables
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_encoded = encoder.fit_transform(X_train[['Type', 'Country']])
X_test_encoded = encoder.transform(X_test[['Type', 'Country']])

# Resetting index before concatenation
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)

# Concatenating encoded features with numerical features
X_train_encoded = np.hstack((X_train.drop(['Type', 'Country'], axis=1), X_train_encoded))
X_test_encoded = np.hstack((X_test.drop(['Type', 'Country'], axis=1), X_test_encoded))

# Creating and fitting the linear regression model
linreg = LinearRegression()
linreg.fit(X_train_encoded, y_train)

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
predictor_names = list(X_train.drop(['Type', 'Country'], axis=1).columns) + encoder.categories_[0][1:].tolist() + encoder.categories_[1][1:].tolist()
print(pd.DataFrame(list(zip(predictor_names, linreg.coef_)), columns=["Predictors", "Coefficients"]))
print()

# Predict Response corresponding to Predictors
y_train_pred = linreg.predict(X_train_encoded)
y_test_pred = linreg.predict(X_test_encoded)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color="blue")
axes[0].plot(y_train, y_train, 'w-', linewidth=1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color="green")
axes[1].plot(y_test, y_test, 'w-', linewidth=1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train_encoded, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test_encoded, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Print the predicted ratings
print("Predicted Ratings on Test Data:")
print(y_test_pred)

predicted_rating_comparison= pd.DataFrame({'Predicted Rating': y_test_pred, 'Actual Rating': y_test})
predicted_rating_comparison
# Out:
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Intercept of Regression 	: b =  43.51506795679947
# Coefficients of Regression 	: a =  [-1.97002048e-02 -6.15914792e-02  5.24053659e-02 -1.58965439e-02
#  -5.27924751e-02  2.89880391e-02 -4.01581540e-01 -9.30528195e-03
#  -3.54256263e-01 -9.92622850e-02 -5.63858431e-01  3.08493092e-01
#   2.95991671e-01  2.41569801e-02  2.03398681e-01  7.57056796e-02
#   6.48313162e-02 -1.12663789e-01 -3.81819341e-02  5.84426857e-02
#   1.54887058e-01  8.31080310e-02 -4.58555794e-01  4.04710066e-01
#   5.01235622e-02  6.91293888e-02 -8.30378163e-02 -4.15069076e-02
#  -1.84656617e-01  1.85134912e-02 -1.27745182e-02  4.50608907e-02
#  -2.05516275e-01  1.18589147e-01  1.37852403e-02 -5.15706989e-04]
#
# ...

# %%
reqData4 = cleaned_wineData[['Year', 'Type', 'Country', 'Rating']]
price4 = cleaned_wineData['Price']

X4 = reqData4
Y4 = price4

predicted_ratings_df = pd.DataFrame(y_test_pred, columns=['Predicted Rating'])

combined_df = pd.concat([X_test.reset_index(drop=True), predicted_ratings_df], axis=1)

combined_df.rename(columns={'Predicted Rating': 'Rating'}, inplace=True)

combined_df
# Out:
#       Year  Type        Country    Rating
# 0     2016     4          Chile  3.684296
# 1     2018     4        Germany  3.819864
# 2     2016     1          Spain  3.786681
# 3     2017     4  United States  3.777644
# 4     2013     1          Italy  3.916998
# ...    ...   ...            ...       ...
# 2189  2016     1          Italy  3.857898
# 2190  2017     1        Romania  3.696717
# 2191  2016     1         France  3.823612
# 2192  2018     4         France  3.768315
# 2193  2018     4          Italy  3.802601
#
# [2194 rows x 4 columns]

# %%
# Split the combined data into features and target variable for price prediction
X_price = combined_df  # Features for price prediction

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X4, Y4, test_size=0.2, random_state=5)

X_test = X_price

# One-hot encoding categorical variables
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_encoded = encoder.fit_transform(X_train[['Type', 'Country']])
X_test_encoded = encoder.transform(X_test[['Type','Country']])

# Resetting index before concatenation
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)

# Concatenating encoded features with numerical features
X_train_encoded = np.hstack((X_train.drop(['Type', 'Country'], axis=1), X_train_encoded))
X_test_encoded = np.hstack((X_test.drop(['Type','Country'], axis=1), X_test_encoded))


# Train a linear regression model to predict price using the combined data
linreg_price = LinearRegression()
linreg_price.fit(X_train_encoded, y_train)

# Predict prices using the trained model on the test set
predicted_prices_test = linreg_price.predict(X_test_encoded)
predicted_prices_train = linreg_price.predict(X_train_encoded)



# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, predicted_prices_train, color="blue")
axes[0].plot(y_train, y_train, 'w-', linewidth=1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, predicted_prices_test, color="green")
axes[1].plot(y_test, y_test, 'w-', linewidth=1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()


# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg_price.score(X_train_encoded, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, predicted_prices_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg_price.score(X_test_encoded, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, predicted_prices_test))
print()


predicted_price_comparison = pd.DataFrame({'Predicted Price': predicted_prices_test, 'Actual Price': y_test})
predicted_price_comparison
# Out:
# /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5262541835772012
# Mean Squared Error (MSE) 	: 89.95159108972648
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.26961009677338454
# Mean Squared Error (MSE) 	: 134.0029271137059
#       Predicted Price  Actual Price
# 3668        14.622296         13.16
# 3556        15.195655          8.50
# 8619        15.585248         12.20
# 2382        21.217649          7.65
# 6018        25.527084         29.90
# ...               ...           ...
# 6766        19.028441          5.49
# 1277        10.830974         13.50
# 7857        23.652006         36.85
# 3090        18.519703         19.69
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dbd5a275-2976-4e4a-b0d0-9abb8341be6f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
